# %%
# %sql
select count(*) from kafka_data.kafka_bronze.kafka_raw_stream

# %%
# %sql
select count(*) from kafka_data.kafka_silver.clean_orders

# %%
# %sql
describe history kafka_data.kafka_bronze.kafka_raw_stream
